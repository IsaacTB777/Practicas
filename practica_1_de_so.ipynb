# %% [markdown]
# <a href="https://colab.research.google.com/github/IsaacTB777/Practicas/blob/main/practica_1_de_so.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys


def MostrarPCB(Pid: int, Etiqueta: str) -> int:


    Campos: list[str] = [
        "Name",
        "State",
        "Pid",
        "PPid",
        "VmSize",
        "VmRSS",
        "voluntary_ctxt_switches",
    ]


    print(f"\n  ┌─ PCB de {Etiqueta} {'─' * (38 - len(Etiqueta))}")
    for Campo in Campos:
        try:
            with open(f"/proc/{Pid}/status") as F:
                for Linea in F:
                    if Linea.startswith(Campo + ":"):
                        # Solo mostramos el valor real — sin descripcion adicional
                        print(f"  │  {Linea.strip()}")
                        break
        except FileNotFoundError:
            print(f"  │  [{Campo}] — proceso {Pid} ya no existe en /proc")


    print(f"  └{'─' * 56}")
    return 0


def Main() -> int:


    print("=" * 60)
    print("  EJERCICIO 1 — Inspeccion del PCB: padre e hijo")
    print("=" * 60)
    print(f"\n  [PADRE] PID: {os.getpid()}")
    print(f"  [PADRE] Mostrando PCB antes del fork...")
    MostrarPCB(os.getpid(), f"PADRE antes del fork  (PID {os.getpid()})")


    print(f"\n  Ejecutando fork()...")
    Pid: int = os.fork()


    if Pid == 0:
        print(f"\n  [HIJO]  fork() retorno 0  →  soy el hijo")
        print(f"  [HIJO]  PID  : {os.getpid()}")
        print(f"  [HIJO]  PPID : {os.getppid()}  (apunta al padre)")
        print(f"  [HIJO]  Mostrando mi PCB...")
        MostrarPCB(os.getpid(), f"HIJO  (PID {os.getpid()}, PPID {os.getppid()})")


        sys.exit(0)


    else:
        print(f"\n  [PADRE] fork() retorno {Pid}  →  soy el padre, cree al hijo PID {Pid}")


        print(f"  [PADRE] Esperando al hijo con waitpid()...")
        os.waitpid(Pid, 1)


        print(f"\n  [PADRE] El hijo termino.")
        print(f"  [PADRE] PID: {os.getpid()}")
        print(f"  [PADRE] Mostrando PCB actualizado (comparar voluntary_ctxt_switches)...")
        MostrarPCB(os.getpid(), f"PADRE despues del fork (PID {os.getpid()})")


        print(f"\n  Programa finalizado.")
        print("=" * 60)
        return 0

if __name__ == "__main__":
    Main()
# Out:
# ============================================================
#   EJERCICIO 1 — Inspeccion del PCB: padre e hijo
# ============================================================
#
#   [PADRE] PID: 515
#   [PADRE] Mostrando PCB antes del fork...
#
#   ┌─ PCB de PADRE antes del fork  (PID 515) ───────
#   │  Name:	python3
#   │  State:	R (running)
#   │  Pid:	515
#   │  PPid:	91
#   │  VmSize:	  664344 kB
#   │  VmRSS:	  103292 kB
#   │  voluntary_ctxt_switches:	142
#   └────────────────────────────────────────────────────────
#
#   Ejecutando fork()...
#
#   [PADRE] fork() retorno 532  →  soy el padre, cree al hijo PID 532
#   [PADRE] Esperando al hijo con waitpid()...
#
#   [PADRE] El hijo termino.
#   [PADRE] PID: 515
#   [PADRE] Mostrando PCB actualizado (comparar voluntary_ctxt_switches)...
#
#   ┌─ PCB de PADRE despues del fork (PID 515) ──────
#   │  Name:	python3
#   │  State:	R (running)
#   │  Pid:	515
#   │  PPid:	91
#   │  VmSize:	  664344 kB
#   │  VmRSS:	  103416 kB
#   │  voluntary_ctxt_switches:	143
#   └────────────────────────────────────────────────────────
#
#   Programa finalizado.
# ============================================================
# ============================================================
#   EJERCICIO 1 — Inspeccion del PCB: padre e hijo
# ============================================================
#
#   [PADRE] PID: 515
#   [PADRE] Mostrando PCB antes del fork...
#
#   ┌─ PCB de PADRE antes del fork  (PID 515) ───────
#   │  Name:	python3
#   │  State:	R (running)
#   │  Pid:	515
#   │  PPid:	91
#   │  VmSize:	  664344 kB
#   │  VmRSS:	  103292 kB
#   │  voluntary_ctxt_switches:	142
#   └────────────────────────────────────────────────────────
#
#   Ejecutando fork()...
#
#   [HIJO]  fork() retorno 0  →  soy el hijo
# /tmp/ipykernel_515/1253030694.py:48: DeprecationWarning: This process (pid=515) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   Pid: int = os.fork()
#   [HIJO]  PID  : 532
#   [HIJO]  PPID : 515  (apunta al padre)
#   [HIJO]  Mostrando mi PCB...
